# %% [markdown]
# # 参考
# https://tkstock.site/2018/06/12/post-402/

# %%
import pandas as pd
from pycoingecko import CoinGeckoAPI
import matplotlib.pyplot as plt
import time
import concurrent.futures

# %% [markdown]
# ## ユニバースを定義する
# Coincheckで購入可能なコインのみ

# %%
universe_list = pd.read_excel("../data/universe.xlsx")
universe_list = list(universe_list["ID"])
universe_list[:5]
# Out:
# ['bitcoin', 'ethereum', 'ethereum-classic', 'lisk', 'ripple']

# %% [markdown]
# ## CoinGechoから仮想通貨の情報を取得する

# %%
# CoinGecko APIクライアントを作成
cg = CoinGeckoAPI()

# 仮想通貨リストを取得
coin_list = cg.get_coins_list()
coin_list_df = pd.DataFrame(coin_list)
coin_list_df.head()
# Out:
#                     id symbol                 name
# 0               01coin    zoc               01coin
# 1               0chain    zcn                  Zus
# 2                 0dog   0dog         Bitcoin Dogs
# 3  0-knowledge-network    0kn  0 Knowledge Network
# 4                0-mee    ome                O-MEE

# %%
# ユニバースのコインのみ抽出
filtered_df = coin_list_df[coin_list_df["id"].isin(universe_list)]
filtered_df.reset_index(inplace = True, drop = True)
filtered_df.head()
# Out:
#               id symbol           name
# 0    avalanche-2   avax      Avalanche
# 1        bitcoin    btc        Bitcoin
# 2   bitcoin-cash    bch   Bitcoin Cash
# 3  blood-crystal     bc  Blood Crystal
# 4   bridged-wbtc   wbtc   Bridged WBTC

# %%
def get_specific_coin_data(coin_id, currency, days):
    """指定されたコインのデータを取得する関数"""
    return cg.get_coin_market_chart_by_id(id=coin_id, vs_currency=currency, days=days)

def fetch_coin_data_with_timeout(row, timeout=5):
    """タイムアウト付きでコインデータを取得する"""
    coin_id = row["id"]
    currency = "jpy"
    days = "365"

    with concurrent.futures.ThreadPoolExecutor() as executor:
        future = executor.submit(get_specific_coin_data, coin_id, currency, days)
        try:
            return future.result(timeout=timeout)  # タイムアウトを設定
        except concurrent.futures.TimeoutError:
            print(f"処理がタイムアウトしました: {coin_id}")
            return None

# コインデータを格納するDataFrame
all_coin_df = pd.DataFrame([])

for i in range(len(filtered_df)):
    specific_coin_data_input = filtered_df.iloc[i]

    # タイムアウト付きでデータ取得
    specific_coin_data = fetch_coin_data_with_timeout(specific_coin_data_input, timeout=5)

    if specific_coin_data:
        # 必要な処理に応じてデータを整形して追加
        coin_data_df = pd.DataFrame(specific_coin_data['prices'], columns=["timestamp", "price"])

        # 列名を変える
        new_col_name = specific_coin_data_input["name"] + "_price"
        coin_data_df.rename({"price": new_col_name}, inplace=True, axis = 1)

        # 横結合
        if i == 0:
            all_coin_df = coin_data_df
        else:
            all_coin_df = pd.merge(all_coin_df, coin_data_df, on = "timestamp", how = "outer")

    time.sleep(30)  # APIの呼び出し間隔を調整
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\ara-d\anaconda3\Lib\site-packages\pycoingecko\api.py:49, in CoinGeckoAPI.__request(self, url, params)
#      48 try:
# ---> 49     response.raise_for_status()
#      50     # self._headers = response.headers
#
# File c:\Users\ara-d\anaconda3\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/bitcoin/market_chart?vs_currency=jpy&days=730
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 26
#      23 specific_coin_data_input = filtered_df.iloc[i]
#      25 # タイムアウト付きでデータ取得
# ---> 26 specific_coin_data = fetch_coin_data_with_timeout(specific_coin_data_input, timeout=5)
#      28 if specific_coin_data:
#      29     # 必要な処理に応じてデータを整形して追加
#      30     coin_data_df = pd.DataFrame(specific_coin_data['prices'], columns=["timestamp", "price"])
#
# Cell In[6], line 14, in fetch_coin_data_with_timeout(row, timeout)
#      12 future = executor.submit(get_specific_coin_data, coin_id, currency, days)
#      13 try:
# ---> 14     return future.result(timeout=timeout)  # タイムアウトを設定
#      15 except concurrent.futures.TimeoutError:
#      16     print(f"処理がタイムアウトしました: {coin_id}")
#
# File c:\Users\ara-d\anaconda3\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File c:\Users\ara-d\anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\ara-d\anaconda3\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[6], line 3, in get_specific_coin_data(coin_id, currency, days)
#       1 def get_specific_coin_data(coin_id, currency, days):
#       2     """指定されたコインのデータを取得する関数"""
# ----> 3     return cg.get_coin_market_chart_by_id(id=coin_id, vs_currency=currency, days=days)
#
# File c:\Users\ara-d\anaconda3\Lib\site-packages\pycoingecko\utils.py:16, in func_args_preprocessing.<locals>.input_args(*args, **kwargs)
#      13 # check in *args for lists and booleans
#      14 args = [arg_preprocessing(v) for v in args]
# ---> 16 return func(*args, **kwargs)
#
# File c:\Users\ara-d\anaconda3\Lib\site-packages\pycoingecko\api.py:227, in CoinGeckoAPI.get_coin_market_chart_by_id(self, id, vs_currency, days, **kwargs)
#     224 kwargs['vs_currency'] = vs_currency
#     225 kwargs['days'] = days
# --> 227 return self.__request(api_url, kwargs)
#
# File c:\Users\ara-d\anaconda3\Lib\site-packages\pycoingecko\api.py:57, in CoinGeckoAPI.__request(self, url, params)
#      55 try:
#      56     content = json.loads(response.content.decode('utf-8'))
# ---> 57     raise ValueError(content)
#      58 # if no json
#      59 except json.decoder.JSONDecodeError:
#
# ValueError: {'error': {'status': {'timestamp': '2024-12-08T13:32:25.552+00:00', 'error_code': 10012, 'error_message': 'Your request exceeds the allowed time range. Public API users are limited to querying historical data within the past 365 days. Upgrade to a paid plan to enjoy full historical data access: https://www.coingecko.com/en/api/pricing. '}}}

# %%
from datetime import datetime

def unix_millis_to_datetime(unix_millis):
    # UNIXミリ秒を秒に変換
    unix_seconds = unix_millis / 1000.0
    
    # datetimeオブジェクトに変換
    dt_object = datetime.utcfromtimestamp(unix_seconds)
    
    return dt_object

# %%
all_coin_df["timestamp"] = all_coin_df["timestamp"].map(unix_millis_to_datetime)

# %%
plt.figure(figsize=(10, 5))
plt.xlabel("Date")
plt.ylabel("Price (JPY)")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.plot(all_coin_df[["timestamp"]], all_coin_df[["Bitcoin_price"]])
plt.show()

# %%
all_coin_df
# Out:
#               timestamp  Avalanche_price  Bitcoin_price  Bitcoin Cash_price  \
# 0   2024-06-12 00:00:00      4951.625689   1.057536e+07        70090.311632
# 1   2024-06-13 00:00:00      5215.370110   1.069702e+07        71250.377569
# 2   2024-06-14 00:00:00      4864.407743   1.047905e+07        67747.881339
# 3   2024-06-15 00:00:00      4770.278164   1.039180e+07        66531.975509
# 4   2024-06-16 00:00:00      4717.956197   1.042070e+07        67636.425051
# ..                  ...              ...            ...                 ...
# 192 2024-12-08 01:08:51              NaN            NaN                 NaN
# 193 2024-12-08 13:05:36              NaN            NaN                 NaN
# 194 2024-12-08 01:05:53              NaN            NaN                 NaN
# 195 2024-12-08 13:08:43              NaN            NaN                 NaN
# 196 2024-12-08 02:12:33              NaN            NaN                 NaN
#
#      Blood Crystal_price  BRIHLO_price  Chiliz_price   Dai_price  \
# 0               1.100337           NaN     18.404192  157.217026
# 1               0.782539           NaN     18.882775  156.864966
# 2               0.651975           NaN     17.662085  157.117029
# 3               0.716312           NaN     17.078782  157.539012
# 4               0.718552           NaN     16.414389  157.335732
# ..                   ...           ...           ...         ...
# 192                  NaN           NaN           NaN         NaN
# 193                  NaN           NaN           NaN         NaN
# 194                  NaN           NaN           NaN         NaN
# 195                  NaN           NaN           NaN         NaN
# 196                  NaN           NaN           NaN         NaN
#
#      Enjin Coin_price  Ethereum_price  Ethereum Classic_price  \
# 0           36.835170   549516.434452             4032.532311
# 1           37.650716   558091.117968             4093.060231
# 2           35.364685   544423.759936             3968.463537
# 3           33.618998   547646.234222             3955.827169
# 4           33.817326   561275.427373             4033.102450
# ..                ...             ...                     ...
# 192               NaN             NaN                     NaN
# 193               NaN             NaN                     NaN
# 194               NaN             NaN                     NaN
# 195               NaN             NaN                     NaN
# 196               NaN             NaN                     NaN
#
#      Immutable_price  IOST_price  Lisk_price  Mona_price  NEM_price  \
# 0           0.826324    1.169329  192.527791         NaN   3.135491
# 1           0.850538    1.220025  194.773388         NaN   3.214546
# 2           0.828960    1.201914  184.783436         NaN   3.078835
# 3           0.831209    1.158770  178.059701         NaN   2.863393
# 4           0.842021    1.179315  177.939789         NaN   2.781725
# ..               ...         ...         ...         ...        ...
# 192              NaN         NaN  208.264772         NaN        NaN
# 193              NaN         NaN         NaN    6.664466        NaN
# 194              NaN         NaN         NaN         NaN   5.755931
# 195              NaN         NaN         NaN         NaN        NaN
# 196              NaN         NaN         NaN         NaN        NaN
#
#      Palette_price  Shiba Inu_price
# 0         5.573541         0.003394
# 1         5.298951         0.003483
# 2         5.396520         0.003326
# 3         5.320311         0.003193
# 4         5.312218         0.003268
# ..             ...              ...
# 192            NaN              NaN
# 193            NaN              NaN
# 194            NaN              NaN
# 195       7.269434              NaN
# 196            NaN         0.004814
#
# [197 rows x 18 columns]
